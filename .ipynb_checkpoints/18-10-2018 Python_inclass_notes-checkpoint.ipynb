# %%
#我copy下来的。
import pandas as pd

# %%
df = pd.read_csv("optionPortfolio.csv")
df.shape
df.columns
# Out:
# Index(['TradeDate', 'Currency', 'Ticker', 'OptionType', 'TradedStockPrice',
#        'NumOptions', 'Strike', 'ExpiryDate'],
#       dtype='object')

# %%
df['Ticker'] .unique()###这里我没有跟上那个column！！！ 什么的。讲义上也没有
# Out:
# array(['CALL', 'PUT'], dtype=object)

# %%
df.info
# Out:
# <bound method DataFrame.info of        TradeDate Currency Ticker OptionType  TradedStockPrice  NumOptions  \
# 0     2013-01-02      USD   CALL         FB         28.000000         860
# 1     2013-01-02      USD   CALL        CHK         15.704825           0
# 2     2013-01-02      USD   CALL        CHK         15.704825         890
# 3     2013-01-03      USD    PUT       AAPL         77.442856         740
# 4     2013-01-03      USD   CALL         FB         27.770000         410
# 5     2013-01-03      USD    PUT       MSFT         27.250000         670
# 6     2013-01-03      USD   CALL       MSFT         27.250000         180
# 7     2013-01-03      USD    PUT       AMZN        258.480011           0
# 8     2013-01-03      USD    PUT       AMZN        258.480011         100
# 9     2013-01-03      USD   CALL         BA         77.470001         160
# 10    2013-01-03      USD    PUT       MSFT         27.250000         670
# ...

# %%
df_ccy = df['Currency']

# %%
type(df_ccy)
# Out:
# pandas.core.series.Series

# %%
def dateConverter(dt):
    dt = dt.replace('-',' ')
    return pd.to_datetime(dt,format = '%Y %m %d', dayfirst = True)

# %%
df['TradeDate'] = df['TradeDate'].apply(dateConverter)

# %%
df['ExpiryDate'] = df['ExpiryDate'].apply(dateConverter)

# %%
#the date is now a datetime
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4307 entries, 0 to 4306
# Data columns (total 8 columns):
# TradeDate           4307 non-null datetime64[ns]
# Currency            4307 non-null object
# Ticker              4307 non-null object
# OptionType          4307 non-null object
# TradedStockPrice    4307 non-null float64
# NumOptions          4307 non-null int64
# Strike              4307 non-null int64
# ExpiryDate          4307 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(3)
# memory usage: 269.3+ KB

# %%
# filters
#df[True,False] 仅返回值为true的列
#df["OptionType" == "PUT"] 
#optiontype is a ticker

# %%
df['Ticker'] == "PUT" #a list of booleans
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# 5        True
# 6       False
# 7        True
# 8        True
# 9       False
# 10       True
# 11      False
# 12       True
# 13       True
# 14       True
# 15      False
# 16      False
# 17       True
# 18      False
# 19       True
# 20      False
# 21       True
# 22       True
# 23       True
# 24      False
# 25      False
# 26      False
# 27       True
# 28       True
# 29       True
#         ...
# 4277     True
# 4278     True
# 4279    False
# 4280     True
# 4281     True
# 4282     True
# 4283    False
# 4284    False
# 4285     True
# 4286    False
# 4287     True
# 4288     True
# 4289    False
# 4290     True
# 4291    False
# 4292     True
# 4293     True
# 4294     True
# 4295     True
# 4296     True
# 4297    False
# 4298    False
# 4299     True
# 4300    False
# 4301    False
# 4302    False
# 4303     True
# 4304    False
# 4305     True
# 4306    False
# ...

# %%
df_puts = df[df['Ticker'] == "PUT"]
df[(df['Ticker']=='PUT') & (df['OptionType'] == "AAPL")].head() #using head only to get some rows~ five rows?
# Out:
#     TradeDate Currency Ticker OptionType  TradedStockPrice  NumOptions  \
# 3  2013-01-03      USD    PUT       AAPL         77.442856         740
# 22 2013-01-10      USD    PUT       AAPL         74.787140         660
# 23 2013-01-10      USD    PUT       AAPL         74.787140          40
# 27 2013-01-11      USD    PUT       AAPL         74.328575          30
# 43 2013-01-17      USD    PUT       AAPL         71.811432         180
#
#     Strike ExpiryDate
# 3       80 2013-12-29
# 22      77 2013-07-09
# 23      75 2014-01-05
# 27      74 2013-07-10
# 43      68 2013-04-17

# %%
import datetime as dt
df[(df['ExpiryDate']< dt.datetime(2013,10,2)) & (df['Ticker'] == "PUT")]
# Out:
#      TradeDate Currency Ticker OptionType  TradedStockPrice  NumOptions  \
# 5   2013-01-03      USD    PUT       MSFT         27.250000         670
# 7   2013-01-03      USD    PUT       AMZN        258.480011           0
# 8   2013-01-03      USD    PUT       AMZN        258.480011         100
# 10  2013-01-03      USD    PUT       MSFT         27.250000         670
# 12  2013-01-04      USD    PUT        XRX         18.735178         650
# 14  2013-01-04      USD    PUT        CHK         16.508987         450
# 17  2013-01-07      USD    PUT         BA         76.129997         650
# 21  2013-01-10      USD    PUT        CHK         15.827814         350
# 22  2013-01-10      USD    PUT       AAPL         74.787140         660
# 27  2013-01-11      USD    PUT       AAPL         74.328575          30
# 30  2013-01-14      USD    PUT         BA         76.550003          70
# 36  2013-01-16      USD    PUT         FB         29.850000         140
# ...

# %%
#Group BY

# %%
df[['NumOptions','Ticker']].groupby(['Ticker']).count()
# Out:
#         NumOptions
# Ticker
# CALL          2093
# PUT           2214

# %%
fileName = "timeSeriesDate.pkl"
panel_data = pd.read_pickle('./timeSeriesData.pkl') #to type it right

# %%
panel_data
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 6 (items) x 1009 (major_axis) x 9 (minor_axis)
# Items axis: Adj Close to Volume
# Major_axis axis: 2012-12-31 00:00:00 to 2016-12-30 00:00:00
# Minor_axis axis: AAPL to ^GSPC

# %%
#Close Price

# %%
# getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = panel_data['Close']

start_date = '2013-01-01'
end_date = '2016-12-31'

all_weekdays = pd.date_range(start = start_date, end= end_date,freq = 'B') #这里的B很重要~ 可以写作每个月 M

all_weekdays
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-07', '2013-01-08', '2013-01-09', '2013-01-10',
#                '2013-01-11', '2013-01-14',
#                ...
#                '2016-12-19', '2016-12-20', '2016-12-21', '2016-12-22',
#                '2016-12-23', '2016-12-26', '2016-12-27', '2016-12-28',
#                '2016-12-29', '2016-12-30'],
#               dtype='datetime64[ns]', length=1044, freq='B')

# %%
close = close.reindex(all_weekdays) 
close.head(10) #panel date object
# Out:
#                  AAPL        AMZN         BA  BLCM        CHK         FB  \
# 2013-01-01        NaN         NaN        NaN   NaN        NaN        NaN
# 2013-01-02  78.432854  257.309998  77.070000   NaN  15.704825  28.000000
# 2013-01-03  77.442856  258.480011  77.470001   NaN  15.865658  27.770000
# 2013-01-04  75.285713  259.149994  77.690002   NaN  16.508987  28.760000
# 2013-01-07  74.842857  268.459991  76.129997   NaN  16.669821  29.420000
# 2013-01-08  75.044289  266.380005  74.129997   NaN  15.969726  29.059999
# 2013-01-09  73.871429  266.350006  76.760002   NaN  16.158941  30.590000
# 2013-01-10  74.787140  265.339996  77.089996   NaN  15.827814  31.299999
# 2013-01-11  74.328575  267.940002  75.160004   NaN  15.960265  31.719999
# 2013-01-14  71.678574  272.730011  76.550003   NaN  16.026489  30.950001
#
#                  MSFT        XRX        ^GSPC
# 2013-01-01        NaN        NaN          NaN
# 2013-01-02  27.620001  18.945982  1462.420044
# ...

# %%
ts = panel_date['Close']['AAPL']
ts
# Out:
# Date
# 2012-12-31     76.024284
# 2013-01-02     78.432854
# 2013-01-03     77.442856
# 2013-01-04     75.285713
# 2013-01-07     74.842857
# 2013-01-08     75.044289
# 2013-01-09     73.871429
# 2013-01-10     74.787140
# 2013-01-11     74.328575
# 2013-01-14     71.678574
# 2013-01-15     69.417145
# 2013-01-16     72.298569
# 2013-01-17     71.811432
# 2013-01-18     71.428574
# 2013-01-22     72.110001
# 2013-01-23     73.430000
# 2013-01-24     64.357140
# 2013-01-25     62.840000
# 2013-01-28     64.261429
# 2013-01-29     65.467140
# 2013-01-30     65.261429
# 2013-01-31     65.070000
# 2013-02-01     64.802856
# 2013-02-04     63.188572
# 2013-02-05     65.405716
# 2013-02-06     65.335716
# 2013-02-07     66.888573
# 2013-02-08     67.854286
# 2013-02-11     68.561432
# 2013-02-12     66.842857
#                  ...
# 2016-11-17    109.949997
# 2016-11-18    110.059998
# 2016-11-21    111.730003
# 2016-11-22    111.800003
# 2016-11-23    111.230003
# ...

# %%
from matplotlib import *

# %%
plot.figure(figsize=(10,8))
ts.plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-e32aacd989d8> in <module>()
# ----> 1 plot.figure(figsize=(10,8))
#       2 ts.plot
#
# NameError: name 'plot' is not defined

# %%
#moving averages()
adj_close = panel_data['Adj Close']
#all_weekdays = pd

msft = adj_close['MSFT']
msft.head()
# Out:
# Date
# 2012-12-31    23.278118
# 2013-01-02    24.071194
# 2013-01-03    23.748732
# 2013-01-04    23.304262
# 2013-01-07    23.260689
# Name: MSFT, dtype: float64

# %%
short_rolling_msft = msft.rolling(window = 20).mean()
long_rolling_msft = msft.rolling(window = 100).mean()

# %%
fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot(1,1,1)

# %%
#correlations
adj_close_rets = adj_close.pct_change()
#fig = plt.figure(figsize = (10,8))
pd.plotting.scatter_matrix(adj_close_rets, diagonal = 'kde', figsize = (10,10)); #没有特别跟上
#回报分布，哪个有更正态的分布！！！好神奇~~~~~

# %%
corr = adj_close_rets.corr()
corr #计算correlation matrix in one go~~~
# Out:
#            AAPL      AMZN        BA      BLCM       CHK        FB      MSFT  \
# AAPL   1.000000  0.224360  0.283993  0.214642  0.128116  0.258299  0.341693
# AMZN   0.224360  1.000000  0.287369  0.177928  0.118584  0.416171  0.373101
# BA     0.283993  0.287369  1.000000  0.205877  0.194466  0.247447  0.313373
# BLCM   0.214642  0.177928  0.205877  1.000000  0.149892  0.216801  0.175065
# CHK    0.128116  0.118584  0.194466  0.149892  1.000000  0.087807  0.149613
# FB     0.258299  0.416171  0.247447  0.216801  0.087807  1.000000  0.289628
# MSFT   0.341693  0.373101  0.313373  0.175065  0.149613  0.289628  1.000000
# XRX    0.265770  0.242715  0.435216  0.276547  0.283725  0.269751  0.338077
# ^GSPC  0.480903  0.505357  0.627960  0.312833  0.342764  0.437800  0.603377
#
#             XRX     ^GSPC
# AAPL   0.265770  0.480903
# AMZN   0.242715  0.505357
# BA     0.435216  0.627960
# BLCM   0.276547  0.312833
# CHK    0.283725  0.342764
# FB     0.269751  0.437800
# ...

# %%
fig = plt.figure(figsize = (10,8))
plt.imshow(corr,cmap = 'hot',interpolation = 'none')#为了输出一个热量图~
plt.colorbar()
plt.xticks(range（len(corr))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-651c292c5714> in <module>()
# ----> 1 fig = plt.figure(figsize = (10,8))
#       2 plt.imshow(corr,cmap = 'hot',interpolation = 'none')#为了输出一个热量图~
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline

# %%
numPoints = 21
x = np.linspace(-5,5,numPoints)
np.random.seed(1)
x
# Out:
# array([-5. , -4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,
#         0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
#normal distributed noise
y = -5 + 3 * x + 4 * np.random.normal(size = x.shape)
#cre
data = pd.DataFrame({'x':x,'y':y})
data
# Out:
#       x          y
# 0  -5.0 -13.502619
# 1  -4.5 -20.947026
# 2  -4.0 -19.112687
# 3  -3.5 -19.791874
# 4  -3.0 -10.538369
# 5  -2.5 -21.706155
# 6  -2.0  -4.020753
# 7  -1.5 -12.544828
# 8  -1.0  -6.723844
# 9  -0.5  -7.497482
# 10  0.0   0.848432
# 11  0.5 -11.740563
# 12  1.0  -3.289669
# 13  1.5  -2.036217
# 14  2.0   5.535078
# 15  2.5  -1.899565
# 16  3.0   3.310287
# 17  3.5   1.988566
# 18  4.0   7.168855
# 19  4.5  10.831261
# 20  5.0   5.597523

# %%
from statsmodels.formula.api import ols
model = ols("y ~ x",data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                     74.51
# Date:                Thu, 18 Oct 2018   Prob (F-statistic):           5.32e-08
# Time:                        11:28:08   Log-Likelihood:                -60.649
# No. Observations:                  21   AIC:                             125.3
# Df Residuals:                      19   BIC:                             127.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.7177      0.997     -5.736      0.000      -7.804      -3.631
# ...

# %%
#time Series Analysis

# %%
import pandas as pd
df = pd.read_pickle

# %%
# scipy --optimization--
